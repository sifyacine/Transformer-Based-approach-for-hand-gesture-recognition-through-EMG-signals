# %%
import time
import numpy as np
from numpy import mean, std
import matplotlib.pyplot as plt
from scipy.io import loadmat, savemat
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, matthews_corrcoef
import tensorflow as tf
from tensorflow.python.keras.layers import Dropout, Layer, Dropout
from tensorflow.python.keras.callbacks import History
import xlsxwriter
from tensorflow.python.keras.regularizers import l2
from tensorflow.python.keras import layers
import keras

# %%
class Time2Vec(Layer):
    def __init__(self, kernel_size=1):
        super(Time2Vec, self).__init__()
        self.k = kernel_size

    def build(self, input_shape):
        self.w0 = self.add_weight(name="w0", shape=(1,), initializer="uniform", trainable=True)
        self.b0 = self.add_weight(name="b0", shape=(1,), initializer="uniform", trainable=True)
        self.w = self.add_weight(name="w", shape=(input_shape[-1], self.k), initializer="uniform", trainable=True)
        self.b = self.add_weight(name="b", shape=(self.k,), initializer="uniform", trainable=True)

    def call(self, inputs):
        v1 = self.w0 * inputs + self.b0
        v2 = tf.math.sin(tf.matmul(inputs, self.w) + self.b)
        return tf.concat([v1, v2], axis=-1)

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(res)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_classes,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = layers.Conv1D(filters=32, kernel_size=8, activation='relu', bias_regularizer='l2')(inputs)
    x = layers.MaxPooling1D(pool_size=17,strides=9)(x)
    x = Dropout(0.3)(x)
    x = layers.BatchNormalization()(x)

    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)

# %%
def evaluate_model(trainX, trainy, testX, testy, sujet):
    verbose, epochs, batch_size = 1, 200, 128
    # Extract dimensions from training data:
    n_timesteps = trainX.shape[1]
    d_model= trainX.shape[2]  # This is 12 in your case
    n_outputs = trainy.shape[1]

    print("Train Data Shape:", trainX.shape)  # (num_samples, sequence_length, 12)
    print("Test Data Shape:", testX.shape)

    # Build the classifier model using the raw input dimension and then projecting internally.
    model = build_model(
       input_shape=(n_timesteps, d_model),
       head_size=128,
       num_heads=12,
       num_classes=n_outputs,
       ff_dim=24,
       num_transformer_blocks=1,
       mlp_units=[128],
       mlp_dropout=0.4,
       dropout=0.25,
    )
    model.summary()

 # Compile the model with categorical crossentropy and Adam optimizer.
    model.compile(loss='categorical_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                  metrics=['accuracy'])


    # Train the model
    start = time.time()
    model.fit(trainX, trainy, epochs=epochs, batch_size=batch_size, verbose=verbose, callbacks=[history])
    train_time = time.time() - start  # seconds

    # Save the model
    model.save(fr'D:\Transformer-Based-approach-for-hand-gesture-recognition-through-EMG-signals\DB2\results\without_time2vec\models\transformer2' + str(sujet) + '_Transformer_model.h5')

    # Evaluate on training data
    loss_train, accuracy_train = model.evaluate(trainX, trainy, batch_size=batch_size, verbose=1)
    start = time.time()
    loss_test, accuracy_test = model.evaluate(testX, testy, batch_size=batch_size, verbose=1)
    test_time = time.time() - start  # seconds

    # Predict on test data and convert predictions to class indices
    y_pred = np.argmax(model.predict(testX), axis=-1)
    testy_indices = [np.argmax(y) for y in testy]

    return loss_train, accuracy_train, loss_test, accuracy_test, y_pred, testy_indices, train_time, test_time


def summarize_results(scores, losses):
    m, s = mean(scores), std(scores)
    mL, sL = mean(losses), std(losses)
    print('\nAccuracy: %.5f (+/-%.5f)' % (m, s))
    print('Loss: %.5f (+/-%.5f)' % (mL, sL))

def run_my_experiment(sujet):
    # Load data from MATLAB file; update the path as needed.
    data = loadmat(fr"D:\Transformer-Based-approach-for-hand-gesture-recognition-through-EMG-signals\DB2\data\v3\normalized\S" + str(sujet) + "_E1_A1_300_200_N.mat")

    train_data = data['train_data']      # shape: (num_train_samples, sequence_length, d_model)
    train_labels = data['train_labels']    # shape: (num_train_samples, num_classes)
    test_data = data['test_data']          # shape: (num_test_samples, sequence_length, d_model)
    test_labels = data['test_labels']      # shape: (num_test_samples, num_classes)

    scores = list()
    losses = list()

    loss_train, score_train, loss_test, score_test, y_pred, testy, train_time, test_time = evaluate_model(
        train_data, train_labels, test_data, test_labels, sujet
    )

    print('>#%d: ' % (sujet))
    print('  train accuracy: %.5f' % (score_train))
    print('  train loss    : %.5f' % (loss_train))
    print('  test accuracy: %.5f' % (score_test))
    print('  test loss    : %.5f' % (loss_test))
    scores.append(score_test)
    losses.append(loss_test)
    summarize_results(scores, losses)

    return loss_train, score_train, loss_test, score_test, y_pred, testy, train_time, test_time

# %%
# Main
# ==============================================================================

globel_perd = []
globel_class = []

globel_perd1 = []
globel_class1 = []

# Create a workbook and add a worksheet.
workbook = xlsxwriter.Workbook(fr'D:\Transformer-Based-approach-for-hand-gesture-recognition-through-EMG-signals\DB2\results\without_time2vec\Trans_rslt.xlsx')
worksheet1 = workbook.add_worksheet('Subjects informations')

# Start from the first cell. Rows and columns are zero indexed.
row = 0

worksheet1.write(row, 0, 'Subject')
worksheet1.write(row, 1, 'Train_time')
worksheet1.write(row, 2, 'Test_time')
worksheet1.write(row, 3, 'Train_acc')
worksheet1.write(row, 4, 'Train_loss')
worksheet1.write(row, 5, 'Test_acc')
worksheet1.write(row, 6, 'Test_loss')
worksheet1.write(row, 7, 'MCC')

history = History()
for i in range(1, 41):
    loss_train, score_train, loss_test, score_test, y_pred, testy, train_time, test_time = run_my_experiment(i)

    globel_perd.append(y_pred)
    globel_class.append(testy)

    globel_perd1.extend(y_pred)
    globel_class1.extend(testy)

    mcc = matthews_corrcoef(testy, y_pred)
    mat = confusion_matrix(testy, y_pred)

    cfm_plot, ax = plot_confusion_matrix(mat, figsize=(10, 10), show_normed=True, show_absolute=False)
    cfm_plot.savefig(fr'D:\Transformer-Based-approach-for-hand-gesture-recognition-through-EMG-signals\DB2\results\without_time2vec\confusion_matrix\S' + str(i) + 'trans_confusion_matrix.png')

    fig, axarr = plt.subplots(figsize=(12, 6), ncols=1)
    plot_renge = int(len(history.history['accuracy']) / i)
    global_renge = len(history.history['accuracy'])
    start_renge = global_renge - plot_renge
    axarr.plot(range(plot_renge), history.history['accuracy'][start_renge: global_renge], label='train score')
    axarr.plot(range(plot_renge), history.history['loss'][start_renge: global_renge], label='train loss')
    axarr.set_xlabel('Number of Epochs', fontsize=18)
    axarr.set_ylabel('Accuracy', fontsize=18)
    axarr.set_ylim([0, 2.5])
    plt.legend()
    plt.show()
    fig.savefig(fr'D:\Transformer-Based-approach-for-hand-gesture-recognition-through-EMG-signals\DB2\results\without_time2vec\graphs\S' + str(i) + 'trans_graphe.png')

    # Sheet informations
    worksheet1.write(i, 0, 'Sujet ' + str(i))
    worksheet1.write(i, 1, train_time)
    worksheet1.write(i, 2, test_time)
    worksheet1.write(i, 3, score_train)
    worksheet1.write(i, 4, loss_train)
    worksheet1.write(i, 5, score_test)
    worksheet1.write(i, 6, loss_test)
    worksheet1.write(i, 7, mcc)

workbook.close()

# Save prediction
new_data = {'pred_labels': globel_perd, 'class_labels': globel_class}
savemat(fr'D:\Transformer-Based-approach-for-hand-gesture-recognition-through-EMG-signals\DB2\results\without_time2vec\trans_global_predection.mat', new_data)

mat = confusion_matrix(globel_class1, globel_perd1)
cfm_plot, ax = plot_confusion_matrix(mat, figsize=(10, 10), show_normed=True, show_absolute=False)
cfm_plot.savefig(fr'D:\Transformer-Based-approach-for-hand-gesture-recognition-through-EMG-signals\DB2\results\without_time2vec\trans_global_confusion_matrix.png')
# Out:
# Train Data Shape: (2141, 300, 12)
# Test Data Shape: (1029, 300, 12)
# Model: "functional_51"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_52      │ (None, 300, 12)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_155 (Conv1D) │ (None, 293, 32)   │      3,104 │ input_layer_52[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_52    │ (None, 31, 32)    │          0 │ conv1d_155[0][0]  │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_255         │ (None, 31, 32)    │          0 │ max_pooling1d_52… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 31, 32)    │        128 │ dropout_255[0][0] │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 31, 32)    │    201,248 │ batch_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_257         │ (None, 31, 32)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 31, 32)    │         64 │ dropout_257[0][0] │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_102 (Add)       │ (None, 31, 32)    │          0 │ layer_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_156 (Conv1D) │ (None, 31, 24)    │        792 │ add_102[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_258         │ (None, 31, 24)    │          0 │ conv1d_156[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_157 (Conv1D) │ (None, 31, 32)    │        800 │ dropout_258[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 31, 32)    │         64 │ conv1d_157[0][0]  │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_103 (Add)       │ (None, 31, 32)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_102[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ add_103[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_102 (Dense)   │ (None, 128)       │      4,224 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_259         │ (None, 128)       │          0 │ dense_102[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_103 (Dense)   │ (None, 15)        │      1,935 │ dropout_259[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 212,359 (829.53 KB)
#  Trainable params: 212,295 (829.28 KB)
#  Non-trainable params: 64 (256.00 B)
# Epoch 1/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 118s 948ms/step - accuracy: 0.1137 - loss: 2.8421
# Epoch 2/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 569ms/step - accuracy: 0.1616 - loss: 2.5315
# Epoch 3/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 490ms/step - accuracy: 0.1773 - loss: 2.4267
# Epoch 4/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 490ms/step - accuracy: 0.2544 - loss: 2.2575
# Epoch 5/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 435ms/step - accuracy: 0.2903 - loss: 2.0985
# Epoch 6/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 491ms/step - accuracy: 0.3386 - loss: 2.0092
# Epoch 7/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 427ms/step - accuracy: 0.3853 - loss: 1.9028
# Epoch 8/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 388ms/step - accuracy: 0.3836 - loss: 1.8952
# Epoch 9/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 439ms/step - accuracy: 0.4064 - loss: 1.8035
# Epoch 10/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 454ms/step - accuracy: 0.4236 - loss: 1.7180
# Epoch 11/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 404ms/step - accuracy: 0.4482 - loss: 1.6939
# Epoch 12/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 13s 556ms/step - accuracy: 0.4505 - loss: 1.6378
# Epoch 13/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 657ms/step - accuracy: 0.4554 - loss: 1.6043
# Epoch 14/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 682ms/step - accuracy: 0.4880 - loss: 1.5693
# Epoch 15/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 500ms/step - accuracy: 0.4938 - loss: 1.5145
# Epoch 16/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 435ms/step - accuracy: 0.4828 - loss: 1.5124
# Epoch 17/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 424ms/step - accuracy: 0.5198 - loss: 1.4600
# Epoch 18/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 386ms/step - accuracy: 0.5023 - loss: 1.4677
# Epoch 19/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 544ms/step - accuracy: 0.5240 - loss: 1.3925
# Epoch 20/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 13s 695ms/step - accuracy: 0.5300 - loss: 1.3995
# Epoch 21/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 514ms/step - accuracy: 0.5259 - loss: 1.3741
# Epoch 22/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 554ms/step - accuracy: 0.5408 - loss: 1.3457
# Epoch 23/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - accuracy: 0.5591 - loss: 1.2906
# Epoch 24/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 324ms/step - accuracy: 0.5755 - loss: 1.2761
# Epoch 25/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - accuracy: 0.5450 - loss: 1.3335
# Epoch 26/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 359ms/step - accuracy: 0.5830 - loss: 1.2200
# Epoch 27/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 421ms/step - accuracy: 0.5966 - loss: 1.2121
# Epoch 28/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 466ms/step - accuracy: 0.5789 - loss: 1.2475
# Epoch 29/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - accuracy: 0.5956 - loss: 1.1756
# Epoch 30/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 415ms/step - accuracy: 0.5843 - loss: 1.2154
# Epoch 31/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 375ms/step - accuracy: 0.6137 - loss: 1.1301
# Epoch 32/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 277ms/step - accuracy: 0.6265 - loss: 1.1132
# Epoch 33/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 305ms/step - accuracy: 0.6330 - loss: 1.1165
# Epoch 34/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 14s 529ms/step - accuracy: 0.6038 - loss: 1.1286
# Epoch 35/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 357ms/step - accuracy: 0.6290 - loss: 1.0930
# Epoch 36/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 337ms/step - accuracy: 0.6260 - loss: 1.1123
# Epoch 37/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 355ms/step - accuracy: 0.6336 - loss: 1.0761
# Epoch 38/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 327ms/step - accuracy: 0.6459 - loss: 1.0887
# Epoch 39/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 342ms/step - accuracy: 0.6456 - loss: 1.0394
# Epoch 40/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 367ms/step - accuracy: 0.6616 - loss: 1.0170
# Epoch 41/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 374ms/step - accuracy: 0.6577 - loss: 1.0135
# Epoch 42/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 363ms/step - accuracy: 0.6486 - loss: 1.0425
# Epoch 43/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 368ms/step - accuracy: 0.6660 - loss: 0.9942
# Epoch 44/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 419ms/step - accuracy: 0.6541 - loss: 1.0106
# Epoch 45/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 370ms/step - accuracy: 0.6619 - loss: 0.9983
# Epoch 46/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 384ms/step - accuracy: 0.6638 - loss: 0.9732
# Epoch 47/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 421ms/step - accuracy: 0.6912 - loss: 0.9803
# Epoch 48/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 428ms/step - accuracy: 0.6867 - loss: 0.9432
# Epoch 49/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 409ms/step - accuracy: 0.6763 - loss: 0.9509
# Epoch 50/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 349ms/step - accuracy: 0.6681 - loss: 0.9604
# Epoch 51/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 374ms/step - accuracy: 0.6826 - loss: 0.9385
# Epoch 52/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 347ms/step - accuracy: 0.6882 - loss: 0.9372
# Epoch 53/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 392ms/step - accuracy: 0.6918 - loss: 0.9118
# Epoch 54/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 452ms/step - accuracy: 0.6847 - loss: 0.8995
# Epoch 55/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 618ms/step - accuracy: 0.7095 - loss: 0.8598
# Epoch 56/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 382ms/step - accuracy: 0.7021 - loss: 0.8876
# Epoch 57/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 304ms/step - accuracy: 0.6970 - loss: 0.8989
# Epoch 58/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 289ms/step - accuracy: 0.7060 - loss: 0.8768
# Epoch 59/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step - accuracy: 0.7021 - loss: 0.8504
# Epoch 60/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 298ms/step - accuracy: 0.7105 - loss: 0.8673
# Epoch 61/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 281ms/step - accuracy: 0.7251 - loss: 0.8632
# Epoch 62/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 297ms/step - accuracy: 0.7109 - loss: 0.8699
# Epoch 63/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - accuracy: 0.7423 - loss: 0.8136
# Epoch 64/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 275ms/step - accuracy: 0.7109 - loss: 0.8250
# Epoch 65/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 291ms/step - accuracy: 0.7263 - loss: 0.8411
# Epoch 66/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 273ms/step - accuracy: 0.7037 - loss: 0.8501
# Epoch 67/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 272ms/step - accuracy: 0.7180 - loss: 0.8403
# Epoch 68/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 276ms/step - accuracy: 0.7146 - loss: 0.8071
# Epoch 69/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 281ms/step - accuracy: 0.7152 - loss: 0.7905
# Epoch 70/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 294ms/step - accuracy: 0.7443 - loss: 0.7752
# Epoch 71/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - accuracy: 0.7222 - loss: 0.8251
# Epoch 72/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 272ms/step - accuracy: 0.7197 - loss: 0.8045
# Epoch 73/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 299ms/step - accuracy: 0.7300 - loss: 0.7889
# Epoch 74/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 279ms/step - accuracy: 0.7260 - loss: 0.8005
# Epoch 75/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 310ms/step - accuracy: 0.7217 - loss: 0.7965
# Epoch 76/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 269ms/step - accuracy: 0.7371 - loss: 0.7586
# Epoch 77/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 315ms/step - accuracy: 0.7360 - loss: 0.7868
# Epoch 78/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.7470 - loss: 0.7653
# Epoch 79/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 358ms/step - accuracy: 0.7460 - loss: 0.7771
# Epoch 80/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - accuracy: 0.7285 - loss: 0.7615
# Epoch 81/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 311ms/step - accuracy: 0.7400 - loss: 0.7896
# Epoch 82/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 301ms/step - accuracy: 0.7374 - loss: 0.7477
# Epoch 83/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 271ms/step - accuracy: 0.7224 - loss: 0.7948
# Epoch 84/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 282ms/step - accuracy: 0.7502 - loss: 0.7491
# Epoch 85/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 275ms/step - accuracy: 0.7631 - loss: 0.7182
# Epoch 86/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 274ms/step - accuracy: 0.7270 - loss: 0.7544
# Epoch 87/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 276ms/step - accuracy: 0.7610 - loss: 0.7229
# Epoch 88/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - accuracy: 0.7791 - loss: 0.6734
# Epoch 89/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 299ms/step - accuracy: 0.7433 - loss: 0.7398
# Epoch 90/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 347ms/step - accuracy: 0.7414 - loss: 0.7534
# Epoch 91/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 523ms/step - accuracy: 0.7463 - loss: 0.7463
# Epoch 92/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 436ms/step - accuracy: 0.7567 - loss: 0.7156
# Epoch 93/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 471ms/step - accuracy: 0.7400 - loss: 0.7467
# Epoch 94/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - accuracy: 0.7547 - loss: 0.7438
# Epoch 95/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 298ms/step - accuracy: 0.7640 - loss: 0.6933
# Epoch 96/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 287ms/step - accuracy: 0.7382 - loss: 0.7261
# Epoch 97/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 396ms/step - accuracy: 0.7497 - loss: 0.7185
# Epoch 98/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 382ms/step - accuracy: 0.7871 - loss: 0.6657
# Epoch 99/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 346ms/step - accuracy: 0.7540 - loss: 0.7096
# Epoch 100/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 496ms/step - accuracy: 0.7884 - loss: 0.6331
# Epoch 101/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 328ms/step - accuracy: 0.7820 - loss: 0.6500
# Epoch 102/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 270ms/step - accuracy: 0.7634 - loss: 0.6967
# Epoch 103/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 339ms/step - accuracy: 0.7809 - loss: 0.6518
# Epoch 104/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 359ms/step - accuracy: 0.7751 - loss: 0.6832
# Epoch 105/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 441ms/step - accuracy: 0.7818 - loss: 0.6702
# Epoch 106/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 294ms/step - accuracy: 0.7951 - loss: 0.6471
# Epoch 107/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 353ms/step - accuracy: 0.7743 - loss: 0.6602
# Epoch 108/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 300ms/step - accuracy: 0.7697 - loss: 0.6687
# Epoch 109/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 341ms/step - accuracy: 0.7653 - loss: 0.6905
# Epoch 110/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 317ms/step - accuracy: 0.7769 - loss: 0.6640
# Epoch 111/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.7794 - loss: 0.6524
# Epoch 112/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 315ms/step - accuracy: 0.7830 - loss: 0.6390
# Epoch 113/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 363ms/step - accuracy: 0.7911 - loss: 0.6133
# Epoch 114/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 362ms/step - accuracy: 0.7860 - loss: 0.6512
# Epoch 115/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 396ms/step - accuracy: 0.7730 - loss: 0.6333
# Epoch 116/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 373ms/step - accuracy: 0.7623 - loss: 0.6724
# Epoch 117/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 388ms/step - accuracy: 0.7847 - loss: 0.6325
# Epoch 118/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 304ms/step - accuracy: 0.7829 - loss: 0.6146
# Epoch 119/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 364ms/step - accuracy: 0.7773 - loss: 0.6408
# Epoch 120/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 294ms/step - accuracy: 0.7903 - loss: 0.6052
# Epoch 121/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 345ms/step - accuracy: 0.7736 - loss: 0.6492
# Epoch 122/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 338ms/step - accuracy: 0.7981 - loss: 0.6216
# Epoch 123/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step - accuracy: 0.7862 - loss: 0.6101
# Epoch 124/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 354ms/step - accuracy: 0.8011 - loss: 0.6143
# Epoch 125/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - accuracy: 0.7841 - loss: 0.6315
# Epoch 126/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - accuracy: 0.8002 - loss: 0.5986
# Epoch 127/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 385ms/step - accuracy: 0.7779 - loss: 0.6280
# Epoch 128/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - accuracy: 0.7946 - loss: 0.6228
# Epoch 129/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 389ms/step - accuracy: 0.8073 - loss: 0.5724
# Epoch 130/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 336ms/step - accuracy: 0.8145 - loss: 0.5877
# Epoch 131/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 330ms/step - accuracy: 0.7872 - loss: 0.6110
# Epoch 132/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 355ms/step - accuracy: 0.7946 - loss: 0.6156
# Epoch 133/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 309ms/step - accuracy: 0.7882 - loss: 0.5965
# Epoch 134/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 296ms/step - accuracy: 0.7832 - loss: 0.6067
# Epoch 135/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 282ms/step - accuracy: 0.8163 - loss: 0.5676
# Epoch 136/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 286ms/step - accuracy: 0.8056 - loss: 0.5421
# Epoch 137/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 246ms/step - accuracy: 0.8051 - loss: 0.5937
# Epoch 138/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 365ms/step - accuracy: 0.8003 - loss: 0.5897
# Epoch 139/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 317ms/step - accuracy: 0.7966 - loss: 0.5821
# Epoch 140/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 323ms/step - accuracy: 0.7908 - loss: 0.5977
# Epoch 141/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 300ms/step - accuracy: 0.8001 - loss: 0.5890
# Epoch 142/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 386ms/step - accuracy: 0.7982 - loss: 0.5985
# Epoch 143/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - accuracy: 0.8276 - loss: 0.5192
# Epoch 144/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - accuracy: 0.7990 - loss: 0.5797
# Epoch 145/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 242ms/step - accuracy: 0.7962 - loss: 0.5562
# Epoch 146/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 244ms/step - accuracy: 0.8113 - loss: 0.5710
# Epoch 147/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 257ms/step - accuracy: 0.8078 - loss: 0.5422
# Epoch 148/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 244ms/step - accuracy: 0.7987 - loss: 0.5806
# Epoch 149/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 245ms/step - accuracy: 0.8063 - loss: 0.5745
# Epoch 150/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 250ms/step - accuracy: 0.8058 - loss: 0.5725
# Epoch 151/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 242ms/step - accuracy: 0.8198 - loss: 0.5406
# Epoch 152/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 248ms/step - accuracy: 0.8308 - loss: 0.5113
# Epoch 153/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 265ms/step - accuracy: 0.8202 - loss: 0.5429
# Epoch 154/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 255ms/step - accuracy: 0.8165 - loss: 0.5563
# Epoch 155/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 241ms/step - accuracy: 0.8071 - loss: 0.5536
# Epoch 156/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 246ms/step - accuracy: 0.8047 - loss: 0.5721
# Epoch 157/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 263ms/step - accuracy: 0.8201 - loss: 0.5130
# Epoch 158/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 269ms/step - accuracy: 0.8073 - loss: 0.5443
# Epoch 159/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 338ms/step - accuracy: 0.8341 - loss: 0.5075
# Epoch 160/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 288ms/step - accuracy: 0.8176 - loss: 0.5506
# Epoch 161/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 314ms/step - accuracy: 0.8090 - loss: 0.5669
# Epoch 162/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - accuracy: 0.8183 - loss: 0.5255
# Epoch 163/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - accuracy: 0.8153 - loss: 0.5342
# Epoch 164/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 299ms/step - accuracy: 0.8212 - loss: 0.5397
# Epoch 165/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 311ms/step - accuracy: 0.8273 - loss: 0.5077
# Epoch 166/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 368ms/step - accuracy: 0.8266 - loss: 0.5124
# Epoch 167/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 283ms/step - accuracy: 0.8105 - loss: 0.5336
# Epoch 168/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 361ms/step - accuracy: 0.8143 - loss: 0.5152
# Epoch 169/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 402ms/step - accuracy: 0.8212 - loss: 0.5169
# Epoch 170/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 279ms/step - accuracy: 0.8198 - loss: 0.5191
# Epoch 171/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 268ms/step - accuracy: 0.8195 - loss: 0.5383
# Epoch 172/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 304ms/step - accuracy: 0.8173 - loss: 0.5191
# Epoch 173/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 326ms/step - accuracy: 0.8171 - loss: 0.5184
# Epoch 174/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 283ms/step - accuracy: 0.8296 - loss: 0.5017
# Epoch 175/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - accuracy: 0.8357 - loss: 0.4850
# Epoch 176/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - accuracy: 0.8431 - loss: 0.4890
# Epoch 177/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 289ms/step - accuracy: 0.8180 - loss: 0.5162
# Epoch 178/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 288ms/step - accuracy: 0.8382 - loss: 0.4992
# Epoch 179/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 299ms/step - accuracy: 0.8318 - loss: 0.5017
# Epoch 180/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - accuracy: 0.8238 - loss: 0.5064
# Epoch 181/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 289ms/step - accuracy: 0.8106 - loss: 0.5115
# Epoch 182/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 292ms/step - accuracy: 0.8153 - loss: 0.5405
# Epoch 183/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 288ms/step - accuracy: 0.8232 - loss: 0.5095
# Epoch 184/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 292ms/step - accuracy: 0.8337 - loss: 0.4827
# Epoch 185/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 288ms/step - accuracy: 0.8160 - loss: 0.5061
# Epoch 186/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 296ms/step - accuracy: 0.8313 - loss: 0.4812
# Epoch 187/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 292ms/step - accuracy: 0.8366 - loss: 0.4766
# Epoch 188/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 298ms/step - accuracy: 0.8380 - loss: 0.4777
# Epoch 189/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 298ms/step - accuracy: 0.8217 - loss: 0.5272
# Epoch 190/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - accuracy: 0.8342 - loss: 0.4780
# Epoch 191/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 300ms/step - accuracy: 0.8353 - loss: 0.5002
# Epoch 192/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 297ms/step - accuracy: 0.8126 - loss: 0.5086
# Epoch 193/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 299ms/step - accuracy: 0.8394 - loss: 0.4860
# Epoch 194/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 297ms/step - accuracy: 0.8408 - loss: 0.4838
# Epoch 195/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 300ms/step - accuracy: 0.8327 - loss: 0.4762
# Epoch 196/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 296ms/step - accuracy: 0.8438 - loss: 0.4821
# Epoch 197/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 301ms/step - accuracy: 0.8455 - loss: 0.4469
# Epoch 198/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 303ms/step - accuracy: 0.8204 - loss: 0.5038
# Epoch 199/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 298ms/step - accuracy: 0.8223 - loss: 0.5183
# Epoch 200/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 303ms/step - accuracy: 0.8361 - loss: 0.4682
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 26s 227ms/step - accuracy: 0.9343 - loss: 0.2382
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 395ms/step - accuracy: 0.8524 - loss: 0.4507
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step
# >#1:
#   train accuracy: 0.91920
#   train loss    : 0.26524
#   test accuracy: 0.83479
#   test loss    : 0.53089
#
# Accuracy: 0.83479 (+/-0.00000)
# Loss: 0.53089 (+/-0.00000)
# Train Data Shape: (2427, 300, 12)
# Test Data Shape: (1209, 300, 12)
# Model: "functional_52"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_53      │ (None, 300, 12)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_158 (Conv1D) │ (None, 293, 32)   │      3,104 │ input_layer_53[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_53    │ (None, 31, 32)    │          0 │ conv1d_158[0][0]  │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_260         │ (None, 31, 32)    │          0 │ max_pooling1d_53… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 31, 32)    │        128 │ dropout_260[0][0] │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 31, 32)    │    201,248 │ batch_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_262         │ (None, 31, 32)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 31, 32)    │         64 │ dropout_262[0][0] │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_104 (Add)       │ (None, 31, 32)    │          0 │ layer_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_159 (Conv1D) │ (None, 31, 24)    │        792 │ add_104[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_263         │ (None, 31, 24)    │          0 │ conv1d_159[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_160 (Conv1D) │ (None, 31, 32)    │        800 │ dropout_263[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 31, 32)    │         64 │ conv1d_160[0][0]  │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_105 (Add)       │ (None, 31, 32)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_104[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ add_105[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_104 (Dense)   │ (None, 128)       │      4,224 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_264         │ (None, 128)       │          0 │ dense_104[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_105 (Dense)   │ (None, 15)        │      1,935 │ dropout_264[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 212,359 (829.53 KB)
#  Trainable params: 212,295 (829.28 KB)
#  Non-trainable params: 64 (256.00 B)
# Epoch 1/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 126s 317ms/step - accuracy: 0.0957 - loss: 2.8851
# Epoch 2/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 257ms/step - accuracy: 0.1918 - loss: 2.5404
# Epoch 3/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 254ms/step - accuracy: 0.2225 - loss: 2.4339
# Epoch 4/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 252ms/step - accuracy: 0.2577 - loss: 2.2974
# Epoch 5/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 249ms/step - accuracy: 0.2941 - loss: 2.2443
# Epoch 6/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 245ms/step - accuracy: 0.3069 - loss: 2.1762
# Epoch 7/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 247ms/step - accuracy: 0.3204 - loss: 2.1078
# Epoch 8/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 257ms/step - accuracy: 0.3332 - loss: 2.0494
# Epoch 9/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 252ms/step - accuracy: 0.3699 - loss: 2.0281
# Epoch 10/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 246ms/step - accuracy: 0.3913 - loss: 1.9478
# Epoch 11/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 244ms/step - accuracy: 0.3768 - loss: 1.9406
# Epoch 12/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 252ms/step - accuracy: 0.4088 - loss: 1.8679
# Epoch 13/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 257ms/step - accuracy: 0.3806 - loss: 1.8380
# Epoch 14/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 242ms/step - accuracy: 0.4449 - loss: 1.7635
# Epoch 15/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 251ms/step - accuracy: 0.4150 - loss: 1.7721
# Epoch 16/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 241ms/step - accuracy: 0.4324 - loss: 1.7328
# Epoch 17/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 249ms/step - accuracy: 0.4592 - loss: 1.7155
# Epoch 18/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 248ms/step - accuracy: 0.4576 - loss: 1.6859
# Epoch 19/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 242ms/step - accuracy: 0.4751 - loss: 1.5989
# Epoch 20/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 245ms/step - accuracy: 0.4795 - loss: 1.6167
# Epoch 21/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 262ms/step - accuracy: 0.4928 - loss: 1.5822
# Epoch 22/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 244ms/step - accuracy: 0.4974 - loss: 1.5488
# Epoch 23/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 251ms/step - accuracy: 0.5061 - loss: 1.5583
# Epoch 24/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 244ms/step - accuracy: 0.4977 - loss: 1.5118
# Epoch 25/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 246ms/step - accuracy: 0.5160 - loss: 1.5181
# Epoch 26/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 244ms/step - accuracy: 0.5186 - loss: 1.4902
# Epoch 27/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 245ms/step - accuracy: 0.5326 - loss: 1.4761
# Epoch 28/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 240ms/step - accuracy: 0.5345 - loss: 1.4535
# Epoch 29/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 244ms/step - accuracy: 0.5283 - loss: 1.4491
# Epoch 30/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 241ms/step - accuracy: 0.5319 - loss: 1.4192
# Epoch 31/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 245ms/step - accuracy: 0.5332 - loss: 1.4161
# Epoch 32/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 239ms/step - accuracy: 0.5376 - loss: 1.4142
# Epoch 33/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 250ms/step - accuracy: 0.5595 - loss: 1.3068
# Epoch 34/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 252ms/step - accuracy: 0.5649 - loss: 1.3311
# Epoch 35/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 245ms/step - accuracy: 0.5527 - loss: 1.3600
# Epoch 36/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 252ms/step - accuracy: 0.5497 - loss: 1.3378
# Epoch 37/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 242ms/step - accuracy: 0.5514 - loss: 1.3157
# Epoch 38/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 246ms/step - accuracy: 0.5625 - loss: 1.3430
# Epoch 39/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 249ms/step - accuracy: 0.5596 - loss: 1.3063
# Epoch 40/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 248ms/step - accuracy: 0.5619 - loss: 1.2936
# Epoch 41/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 247ms/step - accuracy: 0.5725 - loss: 1.2676
# Epoch 42/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 245ms/step - accuracy: 0.6004 - loss: 1.2180
# Epoch 43/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 248ms/step - accuracy: 0.5896 - loss: 1.2435
# Epoch 44/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 247ms/step - accuracy: 0.5667 - loss: 1.2675
# Epoch 45/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 245ms/step - accuracy: 0.5807 - loss: 1.2733
# Epoch 46/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 244ms/step - accuracy: 0.5839 - loss: 1.2289
# Epoch 47/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 250ms/step - accuracy: 0.6129 - loss: 1.1620
# Epoch 48/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 245ms/step - accuracy: 0.5877 - loss: 1.2125
# Epoch 49/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 248ms/step - accuracy: 0.6085 - loss: 1.1799
# Epoch 50/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 248ms/step - accuracy: 0.6148 - loss: 1.1889
# Epoch 51/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 243ms/step - accuracy: 0.6166 - loss: 1.1290
# Epoch 52/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 253ms/step - accuracy: 0.6322 - loss: 1.1310
# Epoch 53/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 244ms/step - accuracy: 0.6213 - loss: 1.1258
# Epoch 54/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 252ms/step - accuracy: 0.6135 - loss: 1.1403
# Epoch 55/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 253ms/step - accuracy: 0.6186 - loss: 1.1580
# Epoch 56/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 247ms/step - accuracy: 0.6387 - loss: 1.0937
# Epoch 57/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 243ms/step - accuracy: 0.6316 - loss: 1.0840
# Epoch 58/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 250ms/step - accuracy: 0.6203 - loss: 1.0923
# Epoch 59/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 296ms/step - accuracy: 0.6170 - loss: 1.1255
# Epoch 60/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 271ms/step - accuracy: 0.6271 - loss: 1.1083
# Epoch 61/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 313ms/step - accuracy: 0.6437 - loss: 1.0499
# Epoch 62/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 259ms/step - accuracy: 0.6412 - loss: 1.0436
# Epoch 63/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 247ms/step - accuracy: 0.6446 - loss: 1.0497
# Epoch 64/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 244ms/step - accuracy: 0.6371 - loss: 1.0675
# Epoch 65/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 250ms/step - accuracy: 0.6329 - loss: 1.0836
# Epoch 66/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 245ms/step - accuracy: 0.6432 - loss: 1.0331
# Epoch 67/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 243ms/step - accuracy: 0.6104 - loss: 1.0755
# Epoch 68/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 247ms/step - accuracy: 0.6428 - loss: 1.0370
# Epoch 69/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 247ms/step - accuracy: 0.6348 - loss: 1.0874
# Epoch 70/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 251ms/step - accuracy: 0.6522 - loss: 0.9940
# Epoch 71/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 241ms/step - accuracy: 0.6501 - loss: 0.9990
# Epoch 72/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 243ms/step - accuracy: 0.6349 - loss: 1.0170
# Epoch 73/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 247ms/step - accuracy: 0.6455 - loss: 1.0036
# Epoch 74/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 239ms/step - accuracy: 0.6593 - loss: 1.0013
# Epoch 75/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 237ms/step - accuracy: 0.6586 - loss: 1.0182
# Epoch 76/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 246ms/step - accuracy: 0.6665 - loss: 0.9779
# Epoch 77/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 243ms/step - accuracy: 0.6708 - loss: 0.9771
# Epoch 78/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 246ms/step - accuracy: 0.6642 - loss: 0.9798
# Epoch 79/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 245ms/step - accuracy: 0.6965 - loss: 0.9546
# Epoch 80/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 245ms/step - accuracy: 0.6736 - loss: 0.9914
# Epoch 81/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 243ms/step - accuracy: 0.6497 - loss: 0.9979
# Epoch 82/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 248ms/step - accuracy: 0.6893 - loss: 0.9112
# Epoch 83/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 248ms/step - accuracy: 0.6934 - loss: 0.9011
# Epoch 84/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 250ms/step - accuracy: 0.6803 - loss: 0.9380
# Epoch 85/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 263ms/step - accuracy: 0.6831 - loss: 0.9523
# Epoch 86/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 244ms/step - accuracy: 0.6718 - loss: 0.9728
# Epoch 87/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 260ms/step - accuracy: 0.6913 - loss: 0.9038
# Epoch 88/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 349ms/step - accuracy: 0.6963 - loss: 0.8729
# Epoch 89/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 337ms/step - accuracy: 0.6951 - loss: 0.9015
# Epoch 90/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 322ms/step - accuracy: 0.6932 - loss: 0.9093
# Epoch 91/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 288ms/step - accuracy: 0.6778 - loss: 0.9163
# Epoch 92/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 281ms/step - accuracy: 0.6826 - loss: 0.9085
# Epoch 93/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - accuracy: 0.6858 - loss: 0.9125
# Epoch 94/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 282ms/step - accuracy: 0.7028 - loss: 0.8675
# Epoch 95/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 353ms/step - accuracy: 0.6821 - loss: 0.9139
# Epoch 96/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 328ms/step - accuracy: 0.6974 - loss: 0.8971
# Epoch 97/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 331ms/step - accuracy: 0.6838 - loss: 0.9030
# Epoch 98/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.6935 - loss: 0.9059
# Epoch 99/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.7126 - loss: 0.8516
# Epoch 100/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 334ms/step - accuracy: 0.7173 - loss: 0.8254
# Epoch 101/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.7027 - loss: 0.8573
# Epoch 102/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 313ms/step - accuracy: 0.7111 - loss: 0.8463
# Epoch 103/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 288ms/step - accuracy: 0.7125 - loss: 0.8301
# Epoch 104/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 286ms/step - accuracy: 0.7148 - loss: 0.8453
# Epoch 105/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 287ms/step - accuracy: 0.6971 - loss: 0.8706
# Epoch 106/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 286ms/step - accuracy: 0.7090 - loss: 0.8346
# Epoch 107/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 303ms/step - accuracy: 0.6875 - loss: 0.8714
# Epoch 108/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 300ms/step - accuracy: 0.7203 - loss: 0.8324
# Epoch 109/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 292ms/step - accuracy: 0.7109 - loss: 0.8670
# Epoch 110/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 295ms/step - accuracy: 0.7182 - loss: 0.7985
# Epoch 111/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 295ms/step - accuracy: 0.7076 - loss: 0.8315
# Epoch 112/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 296ms/step - accuracy: 0.7086 - loss: 0.8395
# Epoch 113/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 305ms/step - accuracy: 0.7235 - loss: 0.8396
# Epoch 114/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 288ms/step - accuracy: 0.7161 - loss: 0.8074
# Epoch 115/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 291ms/step - accuracy: 0.7086 - loss: 0.8041
# Epoch 116/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 295ms/step - accuracy: 0.7080 - loss: 0.8519
# Epoch 117/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - accuracy: 0.7223 - loss: 0.8313
# Epoch 118/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 293ms/step - accuracy: 0.7265 - loss: 0.7985
# Epoch 119/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 297ms/step - accuracy: 0.7249 - loss: 0.8027
# Epoch 120/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 291ms/step - accuracy: 0.7218 - loss: 0.7828
# Epoch 121/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 298ms/step - accuracy: 0.7187 - loss: 0.7722
# Epoch 122/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 294ms/step - accuracy: 0.7398 - loss: 0.7309
# Epoch 123/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 297ms/step - accuracy: 0.7191 - loss: 0.8031
# Epoch 124/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 303ms/step - accuracy: 0.7343 - loss: 0.7723
# Epoch 125/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 298ms/step - accuracy: 0.7427 - loss: 0.7529
# Epoch 126/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 291ms/step - accuracy: 0.7327 - loss: 0.7528
# Epoch 127/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 302ms/step - accuracy: 0.7354 - loss: 0.7680
# Epoch 128/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - accuracy: 0.7452 - loss: 0.7464
# Epoch 129/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 290ms/step - accuracy: 0.7284 - loss: 0.7593
# Epoch 130/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 293ms/step - accuracy: 0.7461 - loss: 0.7556
# Epoch 131/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 296ms/step - accuracy: 0.7532 - loss: 0.7289
# Epoch 132/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 293ms/step - accuracy: 0.7389 - loss: 0.7559
# Epoch 133/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 293ms/step - accuracy: 0.7346 - loss: 0.7715
# Epoch 134/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 290ms/step - accuracy: 0.7247 - loss: 0.7925
# Epoch 135/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 300ms/step - accuracy: 0.7425 - loss: 0.7495
# Epoch 136/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 298ms/step - accuracy: 0.7432 - loss: 0.7387
# Epoch 137/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 290ms/step - accuracy: 0.7298 - loss: 0.7689
# Epoch 138/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 293ms/step - accuracy: 0.7461 - loss: 0.7184
# Epoch 139/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 309ms/step - accuracy: 0.7515 - loss: 0.7102
# Epoch 140/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 306ms/step - accuracy: 0.7500 - loss: 0.7231
# Epoch 141/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 302ms/step - accuracy: 0.7505 - loss: 0.7275
# Epoch 142/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 298ms/step - accuracy: 0.7498 - loss: 0.7174
# Epoch 143/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 302ms/step - accuracy: 0.7561 - loss: 0.7131
# Epoch 144/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 287ms/step - accuracy: 0.7576 - loss: 0.6762
# Epoch 145/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 433ms/step - accuracy: 0.7414 - loss: 0.7381
# Epoch 146/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.7639 - loss: 0.6869
# Epoch 147/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 328ms/step - accuracy: 0.7583 - loss: 0.6951
# Epoch 148/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 285ms/step - accuracy: 0.7695 - loss: 0.6460
# Epoch 149/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 293ms/step - accuracy: 0.7575 - loss: 0.6968
# Epoch 150/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 299ms/step - accuracy: 0.7576 - loss: 0.6915
# Epoch 151/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 302ms/step - accuracy: 0.7757 - loss: 0.6746
# Epoch 152/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 299ms/step - accuracy: 0.7702 - loss: 0.6678
# Epoch 153/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 307ms/step - accuracy: 0.7677 - loss: 0.6647
# Epoch 154/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 301ms/step - accuracy: 0.7652 - loss: 0.6679
# Epoch 155/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.7630 - loss: 0.7043
# Epoch 156/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 293ms/step - accuracy: 0.7760 - loss: 0.6588
# Epoch 157/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 299ms/step - accuracy: 0.7730 - loss: 0.6372
# Epoch 158/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 301ms/step - accuracy: 0.7578 - loss: 0.6829
# Epoch 159/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 352ms/step - accuracy: 0.7737 - loss: 0.6627
# Epoch 160/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 419ms/step - accuracy: 0.7732 - loss: 0.6556
# Epoch 161/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 311ms/step - accuracy: 0.7590 - loss: 0.6757
# Epoch 162/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 296ms/step - accuracy: 0.7964 - loss: 0.6111
# Epoch 163/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 291ms/step - accuracy: 0.7684 - loss: 0.6684
# Epoch 164/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 294ms/step - accuracy: 0.7622 - loss: 0.6539
# Epoch 165/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 310ms/step - accuracy: 0.7763 - loss: 0.6366
# Epoch 166/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s 460ms/step - accuracy: 0.7903 - loss: 0.6262
# Epoch 167/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 373ms/step - accuracy: 0.7714 - loss: 0.6473
# Epoch 168/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 451ms/step - accuracy: 0.7774 - loss: 0.6471
# Epoch 169/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 375ms/step - accuracy: 0.7743 - loss: 0.6563
# Epoch 170/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 368ms/step - accuracy: 0.7701 - loss: 0.6354
# Epoch 171/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 424ms/step - accuracy: 0.7764 - loss: 0.6324
# Epoch 172/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 413ms/step - accuracy: 0.7742 - loss: 0.6550
# Epoch 173/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 420ms/step - accuracy: 0.8022 - loss: 0.6132
# Epoch 174/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 340ms/step - accuracy: 0.7771 - loss: 0.6632
# Epoch 175/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 376ms/step - accuracy: 0.7762 - loss: 0.6223
# Epoch 176/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 503ms/step - accuracy: 0.7841 - loss: 0.6401
# Epoch 177/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 459ms/step - accuracy: 0.7850 - loss: 0.6359
# Epoch 178/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 382ms/step - accuracy: 0.7951 - loss: 0.5949
# Epoch 179/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 396ms/step - accuracy: 0.7944 - loss: 0.6152
# Epoch 180/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 384ms/step - accuracy: 0.7815 - loss: 0.6078
# Epoch 181/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 374ms/step - accuracy: 0.7825 - loss: 0.6338
# Epoch 182/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 368ms/step - accuracy: 0.7919 - loss: 0.6080
# Epoch 183/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 450ms/step - accuracy: 0.7915 - loss: 0.5947
# Epoch 184/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 398ms/step - accuracy: 0.7808 - loss: 0.6246
# Epoch 185/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 409ms/step - accuracy: 0.8000 - loss: 0.5917
# Epoch 186/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 400ms/step - accuracy: 0.7620 - loss: 0.6489
# Epoch 187/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 394ms/step - accuracy: 0.7568 - loss: 0.6692
# Epoch 188/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 399ms/step - accuracy: 0.7970 - loss: 0.5934
# Epoch 189/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 405ms/step - accuracy: 0.7741 - loss: 0.6221
# Epoch 190/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 417ms/step - accuracy: 0.7954 - loss: 0.5908
# Epoch 191/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 422ms/step - accuracy: 0.7981 - loss: 0.6068
# Epoch 192/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 440ms/step - accuracy: 0.7742 - loss: 0.6399
# Epoch 193/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 457ms/step - accuracy: 0.8122 - loss: 0.5533
# Epoch 194/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 422ms/step - accuracy: 0.7863 - loss: 0.5709
# Epoch 195/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 386ms/step - accuracy: 0.7935 - loss: 0.5742
# Epoch 196/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 386ms/step - accuracy: 0.7808 - loss: 0.6120
# Epoch 197/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 402ms/step - accuracy: 0.8061 - loss: 0.5599
# Epoch 198/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 349ms/step - accuracy: 0.8263 - loss: 0.5515
# Epoch 199/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 389ms/step - accuracy: 0.8071 - loss: 0.5351
# Epoch 200/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 344ms/step - accuracy: 0.8044 - loss: 0.5551
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 133ms/step - accuracy: 0.9042 - loss: 0.2674
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 396ms/step - accuracy: 0.8118 - loss: 0.5120
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 19s 325ms/step
# >#2:
#   train accuracy: 0.89534
#   train loss    : 0.30053
#   test accuracy: 0.81969
#   test loss    : 0.52754
#
# Accuracy: 0.81969 (+/-0.00000)
# Loss: 0.52754 (+/-0.00000)
# Train Data Shape: (2361, 300, 12)
# Test Data Shape: (1157, 300, 12)
# Model: "functional_53"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_54      │ (None, 300, 12)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_161 (Conv1D) │ (None, 293, 32)   │      3,104 │ input_layer_54[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_54    │ (None, 31, 32)    │          0 │ conv1d_161[0][0]  │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_265         │ (None, 31, 32)    │          0 │ max_pooling1d_54… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 31, 32)    │        128 │ dropout_265[0][0] │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 31, 32)    │    201,248 │ batch_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_267         │ (None, 31, 32)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 31, 32)    │         64 │ dropout_267[0][0] │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_106 (Add)       │ (None, 31, 32)    │          0 │ layer_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_162 (Conv1D) │ (None, 31, 24)    │        792 │ add_106[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_268         │ (None, 31, 24)    │          0 │ conv1d_162[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_163 (Conv1D) │ (None, 31, 32)    │        800 │ dropout_268[0][0] │
# ...
# Epoch 28/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 335ms/step - accuracy: 0.5679 - loss: 1.3277
# Epoch 29/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.5455 - loss: 1.4027
# Epoch 30/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 305ms/step - accuracy: 0.5665 - loss: 1.3489
# Epoch 31/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 326ms/step - accuracy: 0.5440 - loss: 1.3557
# Epoch 32/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 330ms/step - accuracy: 0.5958 - loss: 1.3095
# Epoch 33/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.5792 - loss: 1.3065
# Epoch 34/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.5744 - loss: 1.3054
# Epoch 35/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 327ms/step - accuracy: 0.5427 - loss: 1.4124
# Epoch 36/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 326ms/step - accuracy: 0.5822 - loss: 1.2825
# Epoch 37/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 338ms/step - accuracy: 0.5887 - loss: 1.2623
# Epoch 38/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step - accuracy: 0.6002 - loss: 1.2429
# Epoch 39/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.6156 - loss: 1.2043
# Epoch 40/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - accuracy: 0.5889 - loss: 1.2593
# Epoch 41/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - accuracy: 0.5819 - loss: 1.2550
# Epoch 42/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 360ms/step - accuracy: 0.5792 - loss: 1.2478
# Epoch 43/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 318ms/step - accuracy: 0.6036 - loss: 1.2045
# Epoch 44/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.5956 - loss: 1.2127
# Epoch 45/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 328ms/step - accuracy: 0.6031 - loss: 1.1863
# Epoch 46/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - accuracy: 0.6259 - loss: 1.1622
# Epoch 47/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 362ms/step - accuracy: 0.6053 - loss: 1.1913
# Epoch 48/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 321ms/step - accuracy: 0.6083 - loss: 1.1914
# Epoch 49/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.6307 - loss: 1.1248
# Epoch 50/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 328ms/step - accuracy: 0.6286 - loss: 1.1150
# Epoch 51/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 336ms/step - accuracy: 0.6450 - loss: 1.1114
# Epoch 52/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.6204 - loss: 1.2083
# Epoch 53/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.6179 - loss: 1.1673
# Epoch 54/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.6524 - loss: 1.0782
# Epoch 55/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 312ms/step - accuracy: 0.6549 - loss: 1.0524
# Epoch 56/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 311ms/step - accuracy: 0.6426 - loss: 1.0557
# Epoch 57/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 326ms/step - accuracy: 0.6493 - loss: 1.0582
# Epoch 58/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 310ms/step - accuracy: 0.6498 - loss: 1.0462
# Epoch 59/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 306ms/step - accuracy: 0.6178 - loss: 1.1108
# Epoch 60/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.6381 - loss: 1.0898
# Epoch 61/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 322ms/step - accuracy: 0.6692 - loss: 1.0308
# Epoch 62/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 326ms/step - accuracy: 0.6548 - loss: 1.0672
# Epoch 63/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 350ms/step - accuracy: 0.6575 - loss: 1.0384
# Epoch 64/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 324ms/step - accuracy: 0.6542 - loss: 1.0461
# Epoch 65/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.6829 - loss: 1.0025
# Epoch 66/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.6587 - loss: 1.0058
# Epoch 67/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 315ms/step - accuracy: 0.6529 - loss: 1.0337
# Epoch 68/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.6727 - loss: 0.9932
# Epoch 69/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 331ms/step - accuracy: 0.6688 - loss: 0.9880
# Epoch 70/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.6777 - loss: 0.9860
# Epoch 71/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 330ms/step - accuracy: 0.6826 - loss: 0.9370
# Epoch 72/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step - accuracy: 0.6678 - loss: 1.0412
# Epoch 73/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - accuracy: 0.6557 - loss: 1.0505
# Epoch 74/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 353ms/step - accuracy: 0.6791 - loss: 0.9801
# Epoch 75/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 300ms/step - accuracy: 0.6848 - loss: 0.9514
# Epoch 76/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 352ms/step - accuracy: 0.6840 - loss: 0.9536
# Epoch 77/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.6982 - loss: 0.9018
# Epoch 78/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 310ms/step - accuracy: 0.6847 - loss: 0.9538
# Epoch 79/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step - accuracy: 0.6954 - loss: 0.9324
# Epoch 80/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 330ms/step - accuracy: 0.6760 - loss: 0.9949
# Epoch 81/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 335ms/step - accuracy: 0.6763 - loss: 0.9675
# Epoch 82/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.6920 - loss: 0.9133
# Epoch 83/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.7042 - loss: 0.8992
# Epoch 84/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step - accuracy: 0.6931 - loss: 0.9296
# Epoch 85/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.6875 - loss: 0.9177
# Epoch 86/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 341ms/step - accuracy: 0.6959 - loss: 0.8919
# Epoch 87/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 322ms/step - accuracy: 0.6832 - loss: 0.9550
# Epoch 88/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 326ms/step - accuracy: 0.6893 - loss: 0.9237
# Epoch 89/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 329ms/step - accuracy: 0.7087 - loss: 0.9439
# Epoch 90/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - accuracy: 0.6961 - loss: 0.9222
# Epoch 91/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 344ms/step - accuracy: 0.6873 - loss: 0.9174
# Epoch 92/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step - accuracy: 0.7160 - loss: 0.8648
# Epoch 93/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 310ms/step - accuracy: 0.7119 - loss: 0.8835
# Epoch 94/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 327ms/step - accuracy: 0.6976 - loss: 0.9062
# Epoch 95/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 331ms/step - accuracy: 0.7084 - loss: 0.8543
# Epoch 96/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.7047 - loss: 0.8581
# Epoch 97/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.7150 - loss: 0.8449
# Epoch 98/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 326ms/step - accuracy: 0.7201 - loss: 0.8253
# Epoch 99/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step - accuracy: 0.7067 - loss: 0.8792
# Epoch 100/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.7134 - loss: 0.8639
# Epoch 101/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step - accuracy: 0.6932 - loss: 0.8690
# Epoch 102/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step - accuracy: 0.7051 - loss: 0.8805
# Epoch 103/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.6962 - loss: 0.8718
# Epoch 104/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 317ms/step - accuracy: 0.7135 - loss: 0.8208
# Epoch 105/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 328ms/step - accuracy: 0.7117 - loss: 0.8435
# Epoch 106/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.7135 - loss: 0.8452
# Epoch 107/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 311ms/step - accuracy: 0.7288 - loss: 0.8183
# Epoch 108/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 318ms/step - accuracy: 0.7400 - loss: 0.7957
# Epoch 109/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 311ms/step - accuracy: 0.7289 - loss: 0.8145
# Epoch 110/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 312ms/step - accuracy: 0.7087 - loss: 0.8197
# Epoch 111/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.7165 - loss: 0.8179
# Epoch 112/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.7070 - loss: 0.8258
# Epoch 113/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 314ms/step - accuracy: 0.7406 - loss: 0.7657
# Epoch 114/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.7309 - loss: 0.7926
# Epoch 115/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.7274 - loss: 0.7877
# Epoch 116/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.7358 - loss: 0.7641
# Epoch 117/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 327ms/step - accuracy: 0.7156 - loss: 0.8469
# Epoch 118/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.7191 - loss: 0.8196
# Epoch 119/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 314ms/step - accuracy: 0.7262 - loss: 0.7957
# Epoch 120/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.7254 - loss: 0.8268
# Epoch 121/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - accuracy: 0.7160 - loss: 0.8174
# Epoch 122/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 329ms/step - accuracy: 0.7316 - loss: 0.7903
# Epoch 123/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 315ms/step - accuracy: 0.7282 - loss: 0.8117
# Epoch 124/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 318ms/step - accuracy: 0.7218 - loss: 0.8096
# Epoch 125/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 300ms/step - accuracy: 0.7083 - loss: 0.8083
# Epoch 126/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.7245 - loss: 0.8010
# Epoch 127/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - accuracy: 0.7600 - loss: 0.7472
# Epoch 128/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - accuracy: 0.7494 - loss: 0.7678
# Epoch 129/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.7415 - loss: 0.7660
# Epoch 130/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 332ms/step - accuracy: 0.7458 - loss: 0.7567
# Epoch 131/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 314ms/step - accuracy: 0.7444 - loss: 0.7668
# Epoch 132/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.7477 - loss: 0.7119
# Epoch 133/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step - accuracy: 0.7435 - loss: 0.7524
# Epoch 134/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 333ms/step - accuracy: 0.7375 - loss: 0.7426
# Epoch 135/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - accuracy: 0.7402 - loss: 0.7768
# Epoch 136/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 328ms/step - accuracy: 0.7401 - loss: 0.7513
# Epoch 137/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step - accuracy: 0.7519 - loss: 0.7377
# Epoch 138/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.7235 - loss: 0.8165
# Epoch 139/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 340ms/step - accuracy: 0.7481 - loss: 0.7409
# Epoch 140/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - accuracy: 0.7444 - loss: 0.7448
# Epoch 141/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 318ms/step - accuracy: 0.7523 - loss: 0.7731
# Epoch 142/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 318ms/step - accuracy: 0.7575 - loss: 0.7124
# Epoch 143/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.7516 - loss: 0.7715
# Epoch 144/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 307ms/step - accuracy: 0.7574 - loss: 0.6969
# Epoch 145/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 381ms/step - accuracy: 0.7558 - loss: 0.6932
# Epoch 146/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.7851 - loss: 0.6767
# Epoch 147/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.7542 - loss: 0.7024
# Epoch 148/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 315ms/step - accuracy: 0.7508 - loss: 0.7213
# Epoch 149/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 330ms/step - accuracy: 0.7555 - loss: 0.7289
# Epoch 150/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.7522 - loss: 0.7246
# Epoch 151/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 329ms/step - accuracy: 0.7721 - loss: 0.6581
# Epoch 152/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 345ms/step - accuracy: 0.7264 - loss: 0.7512
# Epoch 153/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 331ms/step - accuracy: 0.7591 - loss: 0.7011
# Epoch 154/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 345ms/step - accuracy: 0.7448 - loss: 0.7460
# Epoch 155/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 349ms/step - accuracy: 0.7496 - loss: 0.7142
# Epoch 156/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 327ms/step - accuracy: 0.7517 - loss: 0.7084
# Epoch 157/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 339ms/step - accuracy: 0.7593 - loss: 0.6877
# Epoch 158/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.7685 - loss: 0.6947
# Epoch 159/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 314ms/step - accuracy: 0.7566 - loss: 0.6802
# Epoch 160/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - accuracy: 0.7525 - loss: 0.7109
# Epoch 161/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.7423 - loss: 0.7157
# Epoch 162/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 322ms/step - accuracy: 0.7658 - loss: 0.6974
# Epoch 163/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - accuracy: 0.7511 - loss: 0.6941
# Epoch 164/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 326ms/step - accuracy: 0.7753 - loss: 0.6434
# Epoch 165/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step - accuracy: 0.7540 - loss: 0.7104
# Epoch 166/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - accuracy: 0.7829 - loss: 0.6540
# Epoch 167/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 335ms/step - accuracy: 0.7523 - loss: 0.7203
# Epoch 168/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.7833 - loss: 0.6385
# Epoch 169/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 329ms/step - accuracy: 0.7832 - loss: 0.6342
# Epoch 170/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 331ms/step - accuracy: 0.7778 - loss: 0.6626
# Epoch 171/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 337ms/step - accuracy: 0.7853 - loss: 0.6510
# Epoch 172/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 330ms/step - accuracy: 0.7773 - loss: 0.6436
# Epoch 173/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 317ms/step - accuracy: 0.7636 - loss: 0.6577
# Epoch 174/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step - accuracy: 0.7907 - loss: 0.6398
# Epoch 175/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 336ms/step - accuracy: 0.7608 - loss: 0.6778
# Epoch 176/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 308ms/step - accuracy: 0.7811 - loss: 0.6485
# Epoch 177/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 303ms/step - accuracy: 0.7791 - loss: 0.6578
# Epoch 178/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step - accuracy: 0.7627 - loss: 0.6823
# Epoch 179/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - accuracy: 0.7749 - loss: 0.6680
# Epoch 180/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step - accuracy: 0.7812 - loss: 0.6668
# Epoch 181/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 326ms/step - accuracy: 0.7699 - loss: 0.6935
# Epoch 182/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step - accuracy: 0.7842 - loss: 0.6200
# Epoch 183/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 318ms/step - accuracy: 0.7647 - loss: 0.6395
# Epoch 184/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 327ms/step - accuracy: 0.7966 - loss: 0.6014
# Epoch 185/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step - accuracy: 0.7747 - loss: 0.6380
# Epoch 186/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 338ms/step - accuracy: 0.7985 - loss: 0.6010
# Epoch 187/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.7676 - loss: 0.6509
# Epoch 188/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 328ms/step - accuracy: 0.7874 - loss: 0.6222
# Epoch 189/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 334ms/step - accuracy: 0.8067 - loss: 0.5980
# Epoch 190/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 332ms/step - accuracy: 0.7816 - loss: 0.6391
# Epoch 191/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.7936 - loss: 0.6266
# Epoch 192/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - accuracy: 0.7856 - loss: 0.6589
# Epoch 193/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 335ms/step - accuracy: 0.7961 - loss: 0.6169
# Epoch 194/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 308ms/step - accuracy: 0.7987 - loss: 0.5839
# Epoch 195/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 305ms/step - accuracy: 0.8093 - loss: 0.5922
# Epoch 196/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 326ms/step - accuracy: 0.8067 - loss: 0.5942
# Epoch 197/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.8009 - loss: 0.5902
# Epoch 198/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 322ms/step - accuracy: 0.7797 - loss: 0.5876
# Epoch 199/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - accuracy: 0.7824 - loss: 0.6284
# Epoch 200/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.7900 - loss: 0.6090
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.9199 - loss: 0.2320
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 478ms/step - accuracy: 0.8352 - loss: 0.6320
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step
# >#40:
#   train accuracy: 0.88180
#   train loss    : 0.33636
#   test accuracy: 0.79656
#   test loss    : 0.75965
#
# Accuracy: 0.79656 (+/-0.00000)
# Loss: 0.75965 (+/-0.00000)
